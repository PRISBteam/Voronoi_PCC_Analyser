# %%
from importlib import reload

# %%
import matplotlib.pyplot as plt
from matgen import base

# %%
reload(base)
# Out:
# <module 'matgen.base' from '/Users/v94623eb2/Documents/Voronoi_DCC_Analyser/matgen/base.py'>

# %%
filename = 'tests/n8-id1/n8-id1.tess'
c = base.CellComplex.from_tess_file(filename, with_measures=True, with_theta=True, lower_thrd=170, upper_thrd=None)
print(c)
# Out:
# Complex loaded: 0.0 s
# <class CellComplex> 2D
# 18 vertices
# 25 edges
# 8 faces

# %%
ax = c.plot_edges(labels=True)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges()
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges(c='C1', figsize=(10,10))
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges([1,2,3,4], labels=True)
ax = c.plot_edges([18,19,20,21], labels=True, ax=ax)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices(labels=True)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices(c='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], c='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], labels=True)
ax = c.plot_vertices([15,16,17,18], labels=True, ax=ax)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], labels=True, figsize=(4,4))
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
from importlib import reload

# %%
import matplotlib.pyplot as plt
from matgen import base

# %%
reload(base)
# Out:
# <module 'matgen.base' from '/Users/v94623eb2/Documents/Voronoi_DCC_Analyser/matgen/base.py'>

# %%
filename = 'Voronoi_10cells/Voronoi/n10-id1.tess'
c = base.CellComplex.from_tess_file(filename, with_measures=False, with_theta=False, lower_thrd=None, upper_thrd=None)
print(c)
# Out:
# Complex loaded: 0.0 s
# <class CellComplex> 3D
# 54 vertices
# 104 edges
# 61 faces
# 10 polyhedra

# %%
c
# Out:
# <class CellComplex> 3D
# 54 vertices
# 104 edges
# 61 faces
# 10 polyhedra

# %%
poly5 = c.get_one('p', 5)
ax = plt.subplot(111, projection='3d')
for face in c.get_many('f', poly5.f_ids):
    c.plot_edges(face.e_ids, ax=ax)
for face in c.get_many('f', c.get_one('p', 7).f_ids):
    c.plot_edges(face.e_ids, ax=ax)
ax = c.plot_polyhedra([5], ax=ax, color='C1')
ax = c.plot_polyhedra([7], ax=ax, color='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
ax.set_zlim([- 0.1, 1.1])
plt.show()

# %%
ids5 = []
[ids5.extend(face.e_ids) for face in c.get_many('f', c.get_one('p', 5).f_ids)]
# Out:
# [None, None, None, None, None, None, None, None]

# %%
list(set(ids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 list(set(ids))
#
# NameError: name 'ids' is not defined

# %%
ax = c.plot_edges(list(set(ids5)))
ax = c.plot_edges(list(set(ids7)), ax=ax)
ax = c.plot_faces(c.get_one('p', 7).f_ids[:3], ax=ax, color='C1')
ax = c.plot_faces(c.get_one('p', 5).f_ids[:3], ax=ax, color='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges(list(set(ids5)))
ax = c.plot_edges(list(set(ids7)), ax=ax)
ax = c.plot_polyhedra([5], ax=ax, color='C1')
ax = c.plot_polyhedra([7], ax=ax, color='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_faces(c.get_one('p', 7).f_ids)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges()
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges(c='C1', figsize=(10,10))
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_edges([1,2,3,4], labels=True)
ax = c.plot_edges([18,19,20,21], labels=True, ax=ax)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices(labels=True)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
c.plot_edges()
# Out:
# <Axes3DSubplot:>

# %%
ax = c.plot_edges()
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
ax.set_zlim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices(c='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], c='C0')
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], labels=True)
ax = c.plot_vertices([15,16,17,18], labels=True, ax=ax)
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

# %%
ax = c.plot_vertices([1,2,3,4], labels=True, figsize=(4,4))
ax.set_xlim([- 0.1, 1.1])
ax.set_ylim([- 0.1, 1.1])
plt.show()

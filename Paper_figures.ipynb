# %%
from matgen.base import CellComplex
from matgen import matutils
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Figure 3

# %%
x = np.arange(0, 62.8, 0.01)
y = matutils.mackenzie(x)

# %%
np.savetxt('figures_data/Fig3a/x_mackenzie.txt', x, fmt='%.2f')
np.savetxt('figures_data/Fig3a/y_mackenzie.txt', y, fmt='%.5f')

# %% [markdown]
# ### a)

# %%
# filename = '/Users/v94623eb2/Documents/ExpDataAnalysis/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_RandomOri_Cu-0.1Cr-0.1Zr/pass1/disangles/disangles1.txt'
filename = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_RandomOri_Cu-0.1Cr-0.1Zr/pass1/disangles/disangles1.txt'
random_distr2k = np.loadtxt(filename)

# %%
np.savetxt('figures_data/Fig3a/random_distr2k.txt', random_distr2k, fmt='%.2f')

# %%
bins2=[0, 15, 63]
bins32=np.linspace(0, 64, 33)
np.savetxt('figures_data/Fig3a/bins2_boundaries.txt', bins2, fmt='%d')
np.savetxt('figures_data/Fig3a/bins32_boundaries.txt', bins32, fmt='%d')

# %%
hist_points, _ = np.histogram(random_distr2k, bins=[0, 15, 63], density=True)
np.savetxt('figures_data/Fig3a/hist2.txt', hist_points, fmt='%.5f')
hist_points, _ = np.histogram(random_distr2k, bins=np.linspace(0, 64, 33), density=True)
np.savetxt('figures_data/Fig3a/hist32.txt', hist_points, fmt='%.5f')

# %%
# plt.figure(figsize=(6,4))
plt.plot(x, y, linewidth='2') 
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), histtype='step', density=True, linewidth='2')
plt.hist(random_distr2k, bins=[0, 15, 63], histtype='step', density=True, linewidth='2')
plt.tick_params(direction='in')
plt.yticks(ticks=[0.01, 0.02, 0.03, 0.04], labels=[0.01, 0.02, 0.03, 0.04], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.ylim([0, 0.04])
plt.xlim([0, 64])
plt.savefig('Fig3a.png', dpi=300)

# %% [markdown]
# ### b)

# %%
# filename = '/Users/v94623eb2/Documents/ExpDataAnalysis/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_RandomOri_Cu-0.1Cr-0.1Zr/pass4/disangles/disangles1.txt'
filename = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_RandomOri_Cu-0.1Cr-0.1Zr/pass4/disangles/disangles1.txt'
random_distr30k = np.loadtxt(filename)

# %%
np.savetxt('figures_data/Fig3b/random_distr30k.txt', random_distr30k, fmt='%.2f')

# %%
hist_points, _ = np.histogram(random_distr30k, bins=[0, 15, 63], density=True)
np.savetxt('figures_data/Fig3b/hist2.txt', hist_points, fmt='%.5f')
hist_points, _ = np.histogram(random_distr30k, bins=np.linspace(0, 64, 33), density=True)
np.savetxt('figures_data/Fig3b/hist32.txt', hist_points, fmt='%.5f')

# %%
plt.plot(x, y, linewidth='2') 
plt.hist(random_distr30k, bins=np.linspace(0, 64, 33), histtype='step', density=True, linewidth='2')
plt.hist(random_distr30k, bins=[0, 15, 63], histtype='step', density=True, linewidth='2')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0.01, 0.02, 0.03, 0.04], labels=[0.01, 0.02, 0.03, 0.04], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.ylim([0, 0.04])
plt.xlim([0, 64])
plt.savefig('Fig3b.png', dpi=300)

# %% [markdown]
# ## Figure 5

# %%
# filename = '/Users/v94623eb2/Documents/ExpDataAnalysis/DataECAP/Cu_01Cr_01Zr/pass1/disangles1.txt'
filename = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_Cu_01Cr_01Zr/pass1/disangles/disangles1.txt'
disangles = np.loadtxt(filename)

# %%
np.savetxt('figures_data/Fig5a/disangles.txt', disangles, fmt='%.2f')

# %% [markdown]
# ### a)

# %%
hist_points, _ = np.histogram(disangles, bins=[0, 15, 63], density=True)
np.savetxt('figures_data/Fig5a/hist_pass1.txt', hist_points, fmt='%.5f')
hist_points, _ = np.histogram(random_distr2k, bins=[0, 15, 63], density=True)
np.savetxt('figures_data/Fig5a/hist_random.txt', hist_points, fmt='%.5f')

# %%
# plt.plot(x, y) 
#plt.hist(disangles, bins=np.linspace(0, 64, 33), histtype='step', density=True)
plt.hist(disangles, bins=[0, 15, 63], histtype='step', density=True, label='pass 1', linewidth='2')
#plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), histtype='step', density=True)
plt.hist(random_distr2k, bins=[0, 15, 63], histtype='step', density=True, label='random', linewidth='2')
plt.legend(loc='upper left')
plt.title('2 bins', fontsize='x-large')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0, 0.005, 0.01, 0.015, 0.02], labels=[0, 0.005, 0.01, 0.015, 0.02], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
# plt.ylim([0, 0.04])
# plt.xlim([0, 64])
plt.savefig('Fig5a.png', dpi=300)

# %% [markdown]
# ### b)

# %%
hist_points, _ = np.histogram(disangles, bins=np.linspace(0, 64, 33), density=True)
np.savetxt('figures_data/Fig5b/hist_pass1.txt', hist_points, fmt='%.5f')
hist_points, _ = np.histogram(random_distr2k, bins=np.linspace(0, 64, 33), density=True)
np.savetxt('figures_data/Fig5b/hist_random.txt', hist_points, fmt='%.5f')

# %%
# plt.plot(x, y) 
plt.hist(disangles, bins=np.linspace(0, 64, 33), histtype='step', density=True, label='pass 1', linewidth='2')
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), histtype='step', density=True, label='random', linewidth='2')
plt.legend(loc='upper left', fontsize='x-large')
plt.title('32 bins', fontsize='x-large')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0, 0.005, 0.015, 0.025, 0.035], labels=[0, 0.005, 0.015, 0.025, 0.035], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.savefig('Fig5b.png', dpi=300)

# %% [markdown]
# ## Figure 6

# %%
import os

# %% [markdown]
# ### a)

# %%
plt.figure(figsize=(8,6))
# alloy = 'Cu_01Cr_01Zr'
# processing_type = 'ECAP'
# processing_stage = 1
# number_of_cells = 992

dirname = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_Cu_01Cr_01Zr/pass1/disangles'

disangles = {}
for i in range(1, 9):
    filename = os.path.join(dirname, f'disangles{i}.txt')
    disangles[i] = np.loadtxt(filename)

for i in [1, 2, 3, 4, 8]: #range(1, 9):
    plt.hist(disangles[i], bins=np.linspace(0, 64, 33), density=True, histtype='step', label='Neighbour order '+str(i), linewidth='2')
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), density=True, histtype='step', label='baseline', linewidth='2')
plt.legend(loc='upper left', fontsize='x-large')
plt.title('Cu-0.1%Cr-0.1%Zr, pass 1', fontsize='x-large')
# plt.xlabel('Angle of disorientation')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0.005, 0.015, 0.025, 0.035], labels=[0.005, 0.015, 0.025, 0.035], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.xlim([0, 64])
plt.savefig('Fig6a.png', dpi=300)

# %% [markdown]
# ### b)

# %%
plt.figure(figsize=(8,6))
# alloy = 'Cu_01Cr_01Zr'
# processing_type = 'ECAP'
# processing_stage = 1
# number_of_cells = 992

# dirname = '/Users/v94623eb2/Documents/ExpDataAnalysis/DataECAP/Cu_01Cr_01Zr/pass8'
dirname = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_01Cr_01Zr/Neper_Cu_01Cr_01Zr/pass8/disangles'

disangles = {}
for i in range(1, 9):
    filename = os.path.join(dirname, f'disangles{i}.txt')
    disangles[i] = np.loadtxt(filename)

for i in [1, 2, 3, 4, 8]: #range(1, 9):
    plt.hist(disangles[i], bins=np.linspace(0, 64, 33), density=True, histtype='step', label='Neighbour order '+str(i), linewidth='2')
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), density=True, histtype='step', label='baseline', linewidth='2')
plt.legend(loc='upper left')
plt.title('Cu_01Cr_01Zr/pass8')
# plt.xlabel('Angle of disorientation')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0.005, 0.015, 0.025, 0.035], labels=[0.005, 0.015, 0.025, 0.035], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.xlim([0, 64])
plt.legend(loc='upper left', fontsize='x-large')
plt.title('Cu-0.1%Cr-0.1%Zr, pass 8', fontsize='x-large')
plt.savefig('Fig6b.png', dpi=300)

# %% [markdown]
# ### c)

# %%
plt.figure(figsize=(8,6))
# alloy = 'Cu_01Cr_01Zr'
# processing_type = 'ECAP'
# processing_stage = 1
# number_of_cells = 992

# dirname = '/Users/v94623eb2/Documents/ExpDataAnalysis/DataECAP/Cu_01Cr_01Zr/pass8'
dirname = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_Mg_high_temperature_ECAP/Neper_Cu-Mg/pass1/disangles'

disangles = {}
for i in range(1, 9):
    filename = os.path.join(dirname, f'disangles{i}.txt')
    disangles[i] = np.loadtxt(filename)

for i in [1, 2, 3, 4, 8]: #range(1, 9):
    plt.hist(disangles[i], bins=np.linspace(0, 64, 33), density=True, histtype='step', label='order '+str(i), linewidth='2')
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), density=True, histtype='step', label='baseline', linewidth='2')
# plt.legend(loc='upper left')
# plt.xlabel('Angle of disorientation')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0.005, 0.015, 0.025, 0.035], labels=[0.005, 0.015, 0.025, 0.035], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.xlim([0, 64])
# plt.legend(loc='best', fontsize='x-large')
plt.title('Cu-Mg, pass 1', fontsize='x-large')
plt.savefig('Fig6c.png', dpi=300)

# %% [markdown]
# ### d)

# %%
plt.figure(figsize=(8,6))
# alloy = 'Cu_01Cr_01Zr'
# processing_type = 'ECAP'
# processing_stage = 1
# number_of_cells = 992

# dirname = '/Users/v94623eb2/Documents/ExpDataAnalysis/DataECAP/Cu_01Cr_01Zr/pass8'
dirname = 'C:/Users/Oleg/Documents/GitHub/Voronoi_DCC_Analyser/Data/Experimental_Data2/Experimental_Data/ECAP2022/Cu_Mg_high_temperature_ECAP/Neper_Cu-Mg/pass8/disangles'

disangles = {}
for i in range(1, 9):
    filename = os.path.join(dirname, f'disangles{i}.txt')
    disangles[i] = np.loadtxt(filename)

for i in [1, 2, 3, 4, 8]: #range(1, 9):
    plt.hist(disangles[i], bins=np.linspace(0, 64, 33), density=True, histtype='step', label='order '+str(i), linewidth='2')
plt.hist(random_distr2k, bins=np.linspace(0, 64, 33), density=True, histtype='step', label='baseline', linewidth='2')
# plt.legend(loc='upper left')
# plt.xlabel('Angle of disorientation')
plt.tick_params(direction='in', which='both')
plt.yticks(ticks=[0.005, 0.015, 0.025, 0.035], labels=[0.005, 0.015, 0.025, 0.035], fontsize='x-large')
plt.xticks(ticks=[0, 10, 20, 30, 40, 50, 60], labels=[0, 10, 20, 30, 40, 50, 60], fontsize='x-large')
plt.xlim([0, 64])
# plt.legend(loc='best', fontsize='x-large')
plt.title('Cu-Mg, pass 8', fontsize='x-large')
plt.savefig('Fig6d.png', dpi=300)

# %% [markdown]
# ## Figure 7 (q wrt order)

# %%
import pandas as pd
import json

# %%
data_alloy = pd.read_csv('alloy_upd2.csv')

# %%
with open('all_means_100.json', 'r') as fp:
    all_means = json.load(fp)

# %%
with open('all_stds_100.json', 'r') as fp:
    all_stds = json.load(fp)

# %%
data_alloy.head()
# Out:
#                      id                                    filename  \
# 0  Cu_01Cr_01Zr_pass1_1  DataECAP/Cu_01Cr_01Zr/pass1/disangles1.txt
# 1  Cu_01Cr_01Zr_pass1_2  DataECAP/Cu_01Cr_01Zr/pass1/disangles2.txt
# 2  Cu_01Cr_01Zr_pass1_3  DataECAP/Cu_01Cr_01Zr/pass1/disangles3.txt
# 3  Cu_01Cr_01Zr_pass1_4  DataECAP/Cu_01Cr_01Zr/pass1/disangles4.txt
# 4  Cu_01Cr_01Zr_pass1_5  DataECAP/Cu_01Cr_01Zr/pass1/disangles5.txt
#
#           alloy  pass  level        p  N_disangles   H_2bins   H_5bins  \
# 0  Cu_01Cr_01Zr     1      1  0.23548         2858  0.249838  0.275122
# 1  Cu_01Cr_01Zr     1      2  0.17960         6598  0.201651  0.221387
# 2  Cu_01Cr_01Zr     1      3  0.14252        11163  0.166237  0.190621
# 3  Cu_01Cr_01Zr     1      4  0.13200        15992  0.155497  0.181072
# 4  Cu_01Cr_01Zr     1      5  0.11212        20647  0.134122  0.159668
#
#    H_13bins  H_32bins  H_63bins
# 0  0.312578  0.317661  0.320646
# 1  0.250090  0.254014  0.255788
# ...

# %%
data_alloy.alloy.unique()
# Out:
# array(['Cu_01Cr_01Zr', 'Cu_01Cr_01Zr_005Y', 'Cu_03Cr_05Zr', 'Cu_Mg'],
#       dtype=object)

# %%
colors = {
    1: 'C0',
    2: 'C3',
    4: 'C1',
    8: 'C2',
    0: 'C4'
}

# %% [markdown]
# ### a)

# %%
feature = 'p'
alloy = 'Cu_01Cr_01Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
np.savetxt('figures_data/Fig8a/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8a/y1err.txt', yerr, fmt='%.5f')


pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
np.savetxt('figures_data/Fig8a/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8a/y4err.txt', yerr, fmt='%.5f')


pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8a/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8a/y8err.txt', yerr, fmt='%.5f')

plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('q')
plt.savefig('Fig7a.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### b)

# %%
feature = 'p'
alloy = 'Cu_01Cr_01Zr_005Y'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

# pass_ = 1
# x = data.loc[data['pass']==pass_, 'level'].tolist()
# y = data.loc[data['pass']==pass_, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8b/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8b/y4err.txt', yerr, fmt='%.5f')

pass_ = 8
x = data.loc[data['pass']==pass_ , 'level'].tolist()
y = data.loc[data['pass']==pass_ , feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8b/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8b/y8err.txt', yerr, fmt='%.5f')

plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('q')
plt.savefig('Fig7b.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### c)

# %%
feature = 'p'
alloy = 'Cu_03Cr_05Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8c/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8c/y1err.txt', yerr, fmt='%.5f')

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8c/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8c/y4err.txt', yerr, fmt='%.5f')

# pass_ = 8
# x = data.loc[data['pass']==8, 'level'].tolist()
# y = data.loc[data['pass']==8, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])

plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('q')
plt.savefig('Fig7c.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### d)

# %%
feature = 'p'
alloy = 'Cu_Mg'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8d/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8d/y1err.txt', yerr, fmt='%.5f')

pass_ = 2
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8d/y2.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8d/y2err.txt', yerr, fmt='%.5f')

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8d/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8d/y4err.txt', yerr, fmt='%.5f')

pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
np.savetxt('figures_data/Fig8d/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig8d/y8err.txt', yerr, fmt='%.5f')

plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('q')
plt.savefig('Fig7d.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ## Figure 8 (H2 wrt order)

# %% [markdown]
# ### a)

# %%
feature = 'H_2bins'
alloy = 'Cu_01Cr_01Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
plt.plot(x, y_random, color=colors[pass_])

pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
# plt.plot(x, [0] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H2')
plt.savefig('Fig8a.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### b)

# %%
feature = 'H_2bins'
alloy = 'Cu_01Cr_01Zr_005Y'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

# pass_ = 1
# x = data.loc[data['pass']==pass_, 'level'].tolist()
# y = data.loc[data['pass']==pass_, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 8
x = data.loc[data['pass']==pass_ , 'level'].tolist()
y = data.loc[data['pass']==pass_ , feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H2')
plt.savefig('Fig8b.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### c)

# %%
feature = 'H_2bins'
alloy = 'Cu_03Cr_05Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

# pass_ = 8
# x = data.loc[data['pass']==8, 'level'].tolist()
# y = data.loc[data['pass']==8, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H_2bins')
plt.savefig('Fig8c.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### d)

# %%
feature = 'H_2bins'
alloy = 'Cu_Mg'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 2
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H_2bins')
plt.savefig('Fig8d.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ## Figure 9 (H32 wrt order)

# %% [markdown]
# ### a)

# %%
feature = 'H_32bins'
alloy = 'Cu_01Cr_01Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7a/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7a/y1err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7a/y1random.txt', y_random, fmt='%.5f')

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.errorbar(x, y, yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ], linestyle='')
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7a/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7a/y4err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7a/y4random.txt', y_random, fmt='%.5f')


pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
# plt.plot(x, [0] * len(x), label='baseline', color=colors[0])
np.savetxt('figures_data/Fig7a/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7a/y8err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7a/y8random.txt', y_random, fmt='%.5f')


plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H32')
plt.savefig('Fig9a.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %%
np.savetxt('figures_data/Fig7a/order.txt', x, fmt='%d')

# %% [markdown]
# ### b)

# %%
feature = 'H_32bins'
alloy = 'Cu_01Cr_01Zr_005Y'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

# pass_ = 1
# x = data.loc[data['pass']==pass_, 'level'].tolist()
# y = data.loc[data['pass']==pass_, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7b/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7b/y4err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7b/y4random.txt', y_random, fmt='%.5f')

pass_ = 8
x = data.loc[data['pass']==pass_ , 'level'].tolist()
y = data.loc[data['pass']==pass_ , feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7b/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7b/y8err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7b/y8random.txt', y_random, fmt='%.5f')

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H32')
plt.savefig('Fig9b.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### c)

# %%
feature = 'H_32bins'
alloy = 'Cu_03Cr_05Zr'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7c/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7c/y1err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7c/y1random.txt', y_random, fmt='%.5f')

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7c/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7c/y4err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7c/y4random.txt', y_random, fmt='%.5f')

# pass_ = 8
# x = data.loc[data['pass']==8, 'level'].tolist()
# y = data.loc[data['pass']==8, feature].tolist()
# plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H_32bins')
plt.savefig('Fig9c.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')

# %% [markdown]
# ### d)

# %%
feature = 'H_32bins'
alloy = 'Cu_Mg'

data = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['level']<=8)]

pass_ = 1
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' pass', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7d/y1.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7d/y1err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7d/y1random.txt', y_random, fmt='%.5f')

pass_ = 2
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7d/y2.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7d/y2err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7d/y2random.txt', y_random, fmt='%.5f')

pass_ = 4
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7d/y4.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7d/y4err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7d/y4random.txt', y_random, fmt='%.5f')

pass_ = 8
x = data.loc[data['pass']==pass_, 'level'].tolist()
y = data.loc[data['pass']==pass_, feature].tolist()
Ns = data.loc[data_alloy['pass']==pass_, 'N_disangles'].tolist()
plt.scatter(x, y, label=str(pass_) +' passes', color=colors[pass_])
plt.errorbar(
    x, 
    y, 
    yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ],
    linestyle='',
    color=colors[pass_]
)
y_random = [all_means[str(N_disangles)][feature] if N_disangles < 100000 else all_stds['100000'][feature] for N_disangles in Ns]
plt.plot(x, y_random, color=colors[pass_])
np.savetxt('figures_data/Fig7d/y8.txt', y, fmt='%.5f')
yerr=[2.56*all_stds[str(N_disangles)][feature] if N_disangles < 100000 else 0.0005 for N_disangles in Ns ]
np.savetxt('figures_data/Fig7d/y8err.txt', yerr, fmt='%.5f')
np.savetxt('figures_data/Fig7d/y8random.txt', y_random, fmt='%.5f')

# plt.plot(x, [0.02277] * len(x), label='baseline', color=colors[0])

plt.legend()
plt.title(alloy)
plt.xlabel('Neighbour order')
plt.ylabel('H_32bins')
plt.savefig('Fig9d.png', dpi=300)
# for alloy in data_alloy['alloy'].unique().tolist():
#     fig, ax = plt.subplots(figsize=(12,10), tight_layout=True)
#     for pass_ in [1, 2, 4, 8]:
#         #plt.figure(figsize=(12,10))
#         x = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'level'].tolist()
#         y = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), feature].tolist()
#         Ns = data_alloy.loc[(data_alloy['alloy']==alloy)&(data_alloy['pass']==pass_), 'N_disangles'].tolist()
#         if x:
#             ax.scatter(x, y, label=f'pass{pass_}', color=colors[pass_])
#             y_random = [all_means[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns]
#             ax.errorbar(x, y_random, yerr=[2.56*all_stds[N_disangles][feature] if N_disangles < 100000 else all_stds[100000][feature] for N_disangles in Ns], color=colors[pass_], linestyle='')
#             ax.plot(x, y_random, color=colors[pass_])
            
#     ax.set_title(alloy)
#     ax.set_xlim([0, 21])
#     ax.set_xticks([*range(1,21)])
#     ax.set_xlabel('level')
#     ax.set_ylim([0, 0.45])
#     ax.set_ylabel(feature)
#     ax.legend()
#     plt.savefig(feature + '_' + alloy +'.jpg')
